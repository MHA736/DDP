# %%
bilangan= int(input("masukan bilangan :"))
if(bilangan % 2):
 print(f"{bilangan} adalah bilangan ganjil")
else:
 print(f"{bilangan} adalah bilangan genap")
# Out:
# masukan bilangan :8
# 8 adalah bilangan genap

# %%
nilaiUjian= int(input("Masukan Nilai Ujian :"))
if(nilaiUjian >= 75):
 print("Selamat Anda Lulus...Horreee")
elif(nilaiUjian < 75):
 print("Yah Anda Tidak Lulus, silahkan coba lagi")
# Out:
# Masukan Nilai Ujian :60
# Yah Anda Tidak Lulus, silahkan coba lagi

# %%
usiaAnda = int(input("masukan usia anda :"))
if(usiaAnda >= 18):
 print("anda sudah dewasa")
elif(usiaAnda < 18 and usiaAnda >= 13):
 print("anda sudah remaja")
elif(usiaAnda < 13):
 print("anda masih anak anak")
# Out:
# masukan usia anda :7
# anda masih anak anak

# %%
statusKeanggotaan = input("Masukan Status Anda: ")
if statusKeanggotaan == "gold" or statusKeanggotaan == "silver" :
 print("selamat! Anda Mendapatkan Diskon")
elif statusKeanggotaan == "bronze":
 print("anda tidak mendapatkan diskon")
else:
 print("inputan yang anda masukan tidak valid")
# Out:
# Masukan Status Anda: gold
# selamat! Anda Mendapatkan Diskon

# %%
jumlahPembelian = int(input("Masukan jumlah pembelian anda:"))

print(f"Anda mendapatkan diskon 10%") if jumlahPembelian > 100 else print("Anda tidak mendapatkan diskon")
# Out:
# Masukan jumlah pembelian anda:180
# Anda mendapatkan diskon 10%

# %%
kendaraan = ["mio", "motor", "200cc", "biru", "roda2"]
kendaraan.append ("20.000.000")
kendaraan.append ("matic")
print(kendaraan)
kendaraan.insert (2,"Yamaha")
print(kendaraan)
# Out:
# ['mio', 'motor', '200cc', 'biru', 'roda2', '20.000.000', 'matic']
# ['mio', 'motor', 'Yamaha', '200cc', 'biru', 'roda2', '20.000.000', 'matic']

# %%
pilihan= int(input("""pilih nomor pilihan:
1.Menghitung Luas Pesergi
2.Menghitung Luas Lingkaran
3.Menghitung Luas Segitiga
"""))

match pilihan :
 case 1:
  print("Menghitung Luas Persegi")
  s = int(input("Masukkan nilai sisi: "))
  luas_persegi = s * s
  print(f"Luas persegi dengan sisi {s} adalah {luasPersegi}")

 case 2:
   print("Menghitung Luas Lingkaran")
   pi = 3.14
   r = int(input("Masukkan nilai jari-jari"))
   LuasLingkaran = pi * r ** 2
   print(f"Luas Lingkaran dengan jari jari {r} adalah {luasLingkaran}")

 case 3:
  print("Menghitung Luas Segitiga")
  alas = int(input("Masukkan nilai alas: "))
  tinggi = int(input("Masukkan nilai tinggi: "))
  luasSegitiga = 1/2 * alas * tinggi
  print(f"Luas segitiga dengan alas {alas} dan tinggi {tinggi} adalah {luasSegitiga}")

 case _:
  print("input tidak valid")
# Out:
# pilih nomor pilihan:
# 1.Menghitung Luas Pesergi
# 2.Menghitung Luas Lingkaran
# 3.Menghitung Luas Segitiga
# 3
# Menghitung Luas Segitiga
# Masukkan nilai alas: 12
# Masukkan nilai tinggi: 14
# Luas segitiga dengan alas 12 dan tinggi 14 adalah 84.0
